# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('population_data.csv')
df.tail()
# Out:
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 261        Kosovo          XKX  Population, total    SP.POP.TOTL    947000.0
# 262   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5542459.0
# 263  South Africa          ZAF  Population, total    SP.POP.TOTL  16520441.0
# 264        Zambia          ZMB  Population, total    SP.POP.TOTL   3119430.0
# 265      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3806310.0
#
#            1961        1962        1963        1964        1965  ...  \
# 261    966000.0    994000.0   1022000.0   1050000.0   1078000.0  ...
# 262   5646668.0   5753386.0   5860197.0   5973803.0   6097298.0  ...
# 263  16989464.0  17503133.0  18042215.0  18603097.0  19187194.0  ...
# 264   3219451.0   3323427.0   3431381.0   3542764.0   3658024.0  ...
# 265   3925952.0   4049778.0   4177931.0   4310332.0   4447149.0  ...
#
#            2013        2014        2015        2016        2017        2018  \
# ...

# %%
df.shape
# Out:
# (266, 67)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 67 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
# choosing top 20 countries for visualization
a=df.head(20)
a
# Out:
#                    Country Name Country Code     Indicator Name  \
# 0                         Aruba          ABW  Population, total
# 1   Africa Eastern and Southern          AFE  Population, total
# 2                   Afghanistan          AFG  Population, total
# 3    Africa Western and Central          AFW  Population, total
# 4                        Angola          AGO  Population, total
# 5                       Albania          ALB  Population, total
# 6                       Andorra          AND  Population, total
# 7                    Arab World          ARB  Population, total
# 8          United Arab Emirates          ARE  Population, total
# 9                     Argentina          ARG  Population, total
# 10                      Armenia          ARM  Population, total
# 11               American Samoa          ASM  Population, total
# 12          Antigua and Barbuda          ATG  Population, total
# 13                    Australia          AUS  Population, total
# ...

# %%
plt.figure(figsize=(16,8))
sns.barplot(a['Country Name'],a['2022'],data=a,palette='coolwarm')
plt.xlabel('Countries', fontsize=12)
plt.ylabel('Population in 2022', fontsize=12)
plt.title("Countrywise Population in 2022", fontsize=16)
plt.xticks(rotation= 45)
plt.show()

# %%
data = df.groupby('Country Name')['1960','2020','2021','2022'].sum().sort_values(by="2022",ascending=False).head(50).reset_index()
data.head()
# Out:
#           Country Name          1960          2020          2021          2022
# 0                World  3.031474e+09  7.820206e+09  7.888306e+09  7.950947e+09
# 1     IDA & IBRD total  2.297972e+09  6.627317e+09  6.695488e+09  6.754030e+09
# 2  Low & middle income  2.243179e+09  6.549996e+09  6.618837e+09  6.678280e+09
# 3        Middle income  2.107416e+09  5.882943e+09  5.933587e+09  5.974552e+09
# 4            IBRD only  1.904347e+09  4.867092e+09  4.895373e+09  4.913887e+09

# %%
plt.figure(figsize=(16,8))
sns.barplot(data['Country Name'],data['2022'],data=data,palette='cool')
plt.xlabel('Territory/Country', fontsize=12)
plt.ylabel('Population in 2022', fontsize=12)
plt.title("Top 50 Populated Territory in 2022", fontsize=16)
plt.xticks(rotation= 90)
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.barplot(data['Country Name'],data['1960'],data=data,palette='rainbow')
plt.xlabel('Territory/Country', fontsize=12)
plt.ylabel('Population in 1960', fontsize=12)
plt.title("Top 50 Populated Territory in 1960", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
# Count Population of India Over Years

# %%
df1 = df.drop(['Country Code', 'Indicator Name', 'Indicator Code'],axis = 1)
df1.head(2)
# Out:
#                   Country Name         1960         1961         1962  \
# 0                        Aruba      54608.0      55811.0      56682.0
# 1  Africa Eastern and Southern  130692579.0  134169237.0  137835590.0
#
#           1963         1964         1965         1966         1967  \
# 0      57475.0      58178.0      58782.0      59291.0      59522.0
# 1  141630546.0  145605995.0  149742351.0  153955516.0  158313235.0
#
#           1968  ...         2013         2014         2015         2016  \
# 0      59471.0  ...     102880.0     103594.0     104257.0     104874.0
# 1  162875171.0  ...  567892149.0  583651101.0  600008424.0  616377605.0
#
#           2017         2018         2019         2020         2021  \
# 0     105439.0     105962.0     106442.0     106585.0     106537.0
# 1  632746570.0  649757148.0  667242986.0  685112979.0  702977106.0
#
#           2022
# 0     106445.0
# 1  720859132.0
#
# [2 rows x 64 columns]

# %%
ind = df1['Country Name'].isin(['India']).any()
ind
# Out:
# True

# %%
cont = df1[df1['Country Name'] == 'India']
cont
# Out:
#     Country Name         1960         1961         1962         1963  \
# 109        India  445954579.0  456351876.0  467024193.0  477933619.0
#
#             1964         1965         1966         1967         1968  ...  \
# 109  489059309.0  500114346.0  510992617.0  521987069.0  533431909.0  ...
#
#              2013          2014          2015          2016          2017  \
# 109  1.291132e+09  1.307247e+09  1.322867e+09  1.338636e+09  1.354196e+09
#
#              2018          2019          2020          2021          2022
# 109  1.369003e+09  1.383112e+09  1.396387e+09  1.407564e+09  1.417173e+09
#
# [1 rows x 64 columns]

# %%
plt.figure(figsize=(12, 6))
plt.hist(population, bins=20, color='salmon', edgecolor='black')
plt.show()

# %%
cd = df1[df1['Country Name'] == 'India']

years = cd.columns[2:].astype(int)
population = cd.iloc[0, 2:].astype(int)

plt.figure(figsize=(16, 8))
plt.xlabel('Year',fontsize=12)
plt.ylabel('Population',fontsize=12)
plt.title(f'Population of India Over Years (1960 - 2020)',fontsize=16)

plt.bar(years,population,color='lightgreen',edgecolor='black')
plt.show()

# %% [markdown]
# THANK YOU
